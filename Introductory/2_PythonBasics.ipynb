# %% [markdown]
# # Day #1: **Hello World!**
# Let's start coding!

# %%
# This is a code cell. (Wao, nice.)

# you can write comments (text that won't be executed) using the pound sign: #
# you can comment in the same line as executable code, like this:
2 # <- look, it's 2

# hit SHIFT+ENTER to run this cell

# %% [markdown]
# ## Arithmetic

# %% [markdown]
# You can use python as a glorified calculator if you choose. Many basic commands are available in Python, including arithmetic functions. For example, type 2+2 into a code cell and press SHIFT+ENTER.

# %%
2+2 # Run this cell! Click on this cell, then hit SHIFT+ENTER

# %% [markdown]
# Arithmetic operators are `+` for addition, `-` for subtraction, `*` for multiplication, and `/` for division. Raising a value to a power is accomplished by using `**` (e.g. `3**2`). Some less common operators are `%` (modulo) and `//` (integer divide).
#
# Type `a=2` into the next cell. **This will assign the value 2 to the variable a**, which will hold this value until it is reassigned. To reassign `a`, type `a=3` in the subsequent cell.

# %%
# assign 'a' here

# %%
# reassign 'a' here

# %% [markdown]
# You can also redefine the variable based on some algebra, like so
# ```
# a = a + 2
# ```
# and this has a shorthand,
# ```
# a += 2
# ```
# which comes in handy when we want to talk about looping!

# %% [markdown]
# In the cell below, assign a value to `b`. Then, type `c = a+b` and Python will calculate the value of `c`. Note that Python will not print out the result of c automatically unless it is told to do so. To see the value of c, type `print(c)`.

# %%
# try it

# %% [markdown]
# To see all variables, their type, and their value, use the command `%whos`.
#
# Try adding a new cell which prints the variables saved above (without redefining them). You will notice that the variables carry between cells! Each executable cell sends the written code to your Python 'kernel' running in the background. This kernel stays live until you choose to reset it (or sometimes it crashes...).

# %%
# try to print the variables

# %% [markdown]
# Deleting a single variable can be accomplished using the command `del` following by the desired variable (e.g., `del a`). To delete all defined variables, use `%reset`. Check if the deletions were successful using `%whos`.

# %%
# try deleting 'a' here

# %%
# check all the variables here to see if you deleted 'a' successfully

# %% [markdown]
# It is important to note that variable names in Python can consist of numbers, upper and lowercase letters, and underscores. **A variable name cannot start with a number.**
#
# Variable names are generally more useful when they are more descriptive (e.g., `gravity_anomaly` rather than `ga`). **Remember to comment-in details on your variables (longer names, units) to make your code easier to debug.**

# %%
# An example of how I define constants and variables when I'm coding:

rho_ice = 917                         # density of ice, [kg/m3]
T_surf  = 247                         # ice temp at surface, [K]
T_max   = 273.05                      # "curtail the temp"-> max allowed temp (T_max), [K]
c_p     = 2090                        # specific heat of ice, [J/kgK]
k       = 2.22                        # thermal conductivity of ice, [W/mK]
L_heat  = 0.336e6                     # latent heat for melting, [J/kg]
grav    = 9.81 * (60*60*24*365)**2    # gravitational acceleration, [m/yr2]

# Do you notice the long names and the units for everything? This helps me to make sure I am doing
# calculations in the correct units, and with the correct values. 

# You don't have to format your code exactly like this, but including names, units, and 
# other special details in your code is incredibly important.

# %% [markdown]
# ## Wake up, Python!

# %% [markdown]
# The first exercise in any new programming language is to  bring the computer to life with a `Hello World!`

# %%
# Try executing this cell with `Shift+Enter` or 'Ctrl+Enter'
print('Hello World!')

# %% [markdown]
# This is called a 'print statement' and is used to explicity print whatever is indside the parentheses. Inside the print statement, we have a 'string'. To learn more about strings, let's move on to the next notebook. ☺️

# %% [markdown]
# *<div style="text-align: center;"> This notebook was updated with reference to work from (1) Ben Hills (OGIVE) and (2) Yiyu Ni, Anna Ledeczi, and Marine Denolle (ESS 314 Geophysics, Intro to Python). Apologies if you took ESS 314 and recognize the content!</div>*
